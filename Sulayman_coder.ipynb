# %%
print ("hello world")
# Out:
# hello world

# %%
"obed"+" no look at computer no please"
# Out:
# 'obed no look at computer no please'

# %%
"Queen elizibeth"+" the first"
# Out:
# 'Queen elizibeth the first'

# %%
1+99999999999999999999
# Out:
# 100000000000000000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[5,10,15,20]
y=[5,10,15,20]
sns.lineplot(x=x,y=y)
sns.scatterplot(x=x,y=y)
sns.barplot(x=y,y=y)
plt.title("Codes")
plt.show ()

# %%
smart=0
ans=input("what is 0+1")
if ans=="-1":
 smart=smart+1
else:
  print("leave PLEASE!!")
import seaborn
x=["smart"]
y=[smart]
sns.scatterplot(x=x,y=y)
seaborn.barplot(x=x,y=y)
# Out:
# what is 0+1-1
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[0.9,0.8,0.7,0.6,0.5]
y=[0.5,0.6,0.7,0.8,0.9]
sns.barplot
sns.lineplot(x=x,y=y)
sns.scatterplot
plt.title("Codes")
plt.show()

# %%
score=0
ans=input("what is 1+1?")
if ans=="11":
  score=score+1
else:
  print('you wrong')
import seaborn
x=["score"]
y=[score]
seaborn.barplot(x=x,y=y)
# Out:
# what is 1+1?11
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=["Nathan","Sulaimon","Jordan","Annika","Nahum"]
y=[1,1,0.6,1,-1]
sns.barplot(x=x,y=y)
sns.lineplot(x=x,y=0)
plt.title("Are You A Sigma?")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[76438926589246587947254,76438926589246587947254,76438926589246587947254,76438926589246587947254]
sns.barplot(x=x,y=y)
plt.title("How much Nathan gets in trouble")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[404,404,404,404,404]
y=[4,8,3,9,-5]
sns.barplot(x=x,y=y)
sns.barplot(x=y,y=x)
sns.barplot(x=y,y=y)
plt.title(40404040404040404)
plt.show()

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Cool", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Cool"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Cool](data:image/png;base64,...)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[3,4,5,6,7,8,9,21,22,23]
y=[-10,-20,6,9,12,23,42,26,24,23]
sns.scatterplot(x=x,y=y)
sns.barplot(x=x,y=y)
sns.lineplot(x=x,y=y)
plt.title("Ronaldo goals during the years")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=(1,2,3,4,5)
y=(1,2,3,4,5)
sns.scatterplot(x=x,y=y)
sns.lineplot(x=x,y=y)
sns.barplot(x=x,y=y)
plt.title("Meto")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[2,4,6,8,10,12]
sns.scatterplot(x=x,y=y)
sns.barplot(x=x,y=y)
sns.lineplot(x=x,y=y)
plt.title("12345")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[3,4,5,6,7,8,9,21,22,23]
y=[-5,-1,6,9,12,23,42,26,24,23]
sns.scatterplot(x=x,y=y)
sns.barplot(x=x,y=y)
sns.lineplot(x=x,y=y)
plt.title("ɹoɹɹǝERRORɹoɹɹǝERRORERRORE")
plt.show()

# %%
import random

def guess_the_number():
  print("Welcome to the Number Guessing Game!")
  print("I'm  thinking of a number between 1 and 1000.")

  # Computer randomly picks a number
  number = random.randint(1, 1000.)
  attempts = 0

  while True:
    # Ask the user to guess the number
    guess = input("Enter your guess: ")

    # Make sure the input is a number
    if not guess.isdigit():
      print("Please enter a valid number.")
      continue

    guess = int(guess)

    attempts += 1

    # Check the guess
    if guess < number:
        print("Too low! Try again.")
    elif guess > number:
        print("Too high! Try again.")
    else:
        print(f"Congratulations! You've guessed the number {number} in {attempts} attempts.")
        break

# Run the game
guess_the_number()

# %%
import random
points = 0
attempts = 0
while True:
  n1 = random.randint(1, 999)
  n2 = random.ranint(20,500)
  ans = n1 + n2
  resp = input("What is {n1}+{n2}?")
  if resp == ans:
    print("That's Right! You get a point! now how about THIS one:")
    points = points + 1
  else:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[1,2.2,3,4.4,9]
y=[2,4,6,8,10]
sns.barplot(x=x,y=y)
plt.title("Random Scores")
plt.show()

# %%
import random

# Sample word list (5-letter words)
word_list = ["apple", "berry", "cherry", "grape", "peach", "melon", "lemon", "plum", "mango", "apric"]

# Select a random word from the list
target_word = random.choice(word_list)

# Function to check the guess and give feedback
def check_guess(target, guess):
    feedback = []
    for i in rabge(len(target)):
      if guess[i] == target[i]:
        feedback.append(f"{guess[i].upper}()") # Correct letter and and position (green)
      elif guess[i] in target:
           feedback.append(f"{guess[i].lower()}") # Correct letter but wrong position (yellow)
      else:
          feedback.append("_") # Incorrect letter (gray)

    return ''.join(feedback)

# Function to play the game
def play_wordle():
    print("Welcome to the Wordle!")
    print("You have 6 attempts to guess th 5-letter word.")
    attempts = 6

    while attempts > 0:
        guess = input(f"\nAttempt {7 - attempts}/6 - Enter your guess (5 letters): ").lower()

        #va

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
import random
score = 0
attempts = 0

while True:
  computeract = random.choice(['rock','paper','scissors'])
  user_choice = input("Pick rock, Paper, Or Scissors")
  print(f"The computer chose {computeract}")

  # Who's The Winner?

  if user_choice == computeract:
    print("It's A Tie!!")
  elif (user_choice == 'rock' and computeract =='scissors') or \
    (user_choice == 'scissors' and computeract =='paper') or \
    (user_choice == 'paper' and computeract =='rock'):
    print("YOU WIN!! Lets Try Again!!")
    score = score+1
  else:
    print("Oh no, you lose. TRY AGAIN!!")
  attempts = attempts + 1
  if attempts == 20 :
    break
  continue

import seaborn
x=['Your Score','Total Attempts']
y=[score,15]
seaborn.barplot(x=x,y=y)
if score > 7:
  print("U WIN")
else:
  ('U Lose')
# Out:
# Pick rock, Paper, Or Scissorsrock
# The computer chose rock
# It's A Tie!!
# Pick rock, Paper, Or Scissorsrock
# The computer chose scissors
# YOU WIN!! Lets Try Again!!
# Pick rock, Paper, Or Scissorspaper
# The computer chose paper
# It's A Tie!!
# Pick rock, Paper, Or Scissorspaper
# The computer chose scissors
# Oh no, you lose. TRY AGAIN!!
# Pick rock, Paper, Or Scissorsrock
# The computer chose paper
# Oh no, you lose. TRY AGAIN!!
# Pick rock, Paper, Or Scissorsscissors
# The computer chose paper
# YOU WIN!! Lets Try Again!!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=[3,4,5,6,7,8,9,21,22,23]
y=[-5,-1,6,9,12,23,42,26,24,23]
sns.scatterplot(x=x,y=y)
sns.barplot(x=x,y=y)
plt.title("Ronaldo goals during the years")
plt.show()

# Open The Folium Library
import folium

# %%
# prompt: make wordle

import random

def choose_word():
    words = ["crane", "rural", "abbey", "apple", "berry", "cherry", "grape", "peach", "melon", "lemon", "plum", "mango", "apric" "About",	"Alert",	"Argue",	"Beach", "Above",	"Alike", "Arise", "Began", "Abuse", "Array",	"Begin", "Actor",	"Allow",	"Aside",	"Begun", "acute",	"Alone",	"Asset",	"Being", "Admit",	"Along",	"Audio",	"Below", "Adopt",	"Alter",	"Audit",	"Bench", "Adult", "Among", "Avoid", "Billy", "After", "Anger",	"Award",	"Birth", "Again",	"Angle",	"Aware",	"Black", "Agent",	"Angry", "Badly",	"Blame", "Agree",	"Apart",	"Baker",	"Blind", "Ahead",	"Apple",	"Bases",	"Block", "Alarm",	"Apply",	Basic,	Blood, Album,	Arena,	Basis,	Board, Boost,	Buyer,	China,	Cover, Booth,	Cable,	Chose,	Craft, Bound,	Calif,	Civil,	Crash, Brain,	Carry,	Claim,	Cream, Brand,	Catch,	Class,	Crime, Bread,	Cause,	Clean,	Cross, Break,	Chain,	Clear,	Crowd, Breed,	Chair,	Click,	Crown, Brief,	Chart,	Clock	Curve Bring	Chase	Close	Cycle Broad	Cheap	Coach	Daily Broke	Check	Coast	Dance Brown	Chest	Could	Dated Build	Chief	Count	Dealt Built	Child	Court	Death Debut	Entry	Forth	Group Delay	Equal	Forty	Grown Depth	Error	Forum	Guard Doing	Event	Found	Guess Doubt	Every	Frame	Guest Dozen	Exact	Frank	Guide Draft	Exist	Fraud	Happy Drama	Extra	Fresh	Harry Drawn	Faith	Front	Heart Dream	False	Fruit	Heavy Dress	Fault	Fully	Hence Drill	Fibre	Funny	Night Drink	Field	Giant	Horse Drive	Fifth	Given	Hotes Drove	Fifty	Glass	House Dying	Fight	Globe	Human Eager	Final	Going	Ideal Early	First	Grace	Image Earth	Fixed	Grade	Index Eight	Flash	Grand	Inner Elite	Fleet	Grant	Input Empty	Floor	Grass	Issue Enemy	Fluid	Great	Irony Enjoy	Focus	Green	Juice Enter	Force	Gross	Joint Judge	Metal	Media	Newly Known	Local	Might	Noise Label	Logic	Minor	North Large	Loose	Minus	Noted Laser	Lower	Mixed	Novel Later	Lucky	Model	Nurse Laugh	Lunch	Money	Occur Layer	Lying	Month	Ocean Learn	Magic	Moral	Offer Lease	Major	Motor	Often Least	Maker	Mount	Order Leave	March	Mouse	Other Legal	Music	Mouth	Ought Level	Match	Movie	Paint Light	Mayor	Needs	Paper Limit	Meant	Never	Party Peace	Power	Radio	Round Panel	Press	Raise	Route Phase	Price	Range	Royal Phone	Pride	Rapid	Rural Photo	Prime	Ratio	Scale Piece	Print	Reach	Scene Pilot	Prior	Ready	Scope Pitch	Prize	Refer	Score Place	Proof	Right	Sense Plain	Proud	Rival	Serve Plane	Prove	River	Seven Plant	Queen	Quick	Shall Plate	Sixth	Stand	Shape Point	Quiet	Roman	Share Pound	Quite	Rough	Sharp Sheet	Spare	Style	Times Shelf	Speak	Sugar	Tired Shell	Speed	Suite	Title Shift	Spend	Super	Today Shirt	Spent	Sweet	Topic Shock	Split	Table	Total Shoot	Spoke	Taken	Touch Short	Sport	Taste	Tough Shown	Staff	Taxes	Tower Sight	Stage	Teach	Track Since	Stake	Teeth	Trade Sixty	Start	Texas	Treat Sized	State	Thank	Trend Skill	Steam	Theft	Trial Sleep	Steel	Their	Tried Slide	Stick	Theme	Tries Small	Still	There	Truck Smart	Stock	These	Truly Smile	Stone	Thick	Trust Smith	Stood	Thing	Truth Smoke	Store	Think	Twice Solid	Storm	Third	Under Solve	Story	Those	Undue Sorry	Strip	Three	Union Sound	Stuck	Threw	Unity South	Study	Throw	Until Space	Stuff	Tight	Upper Upset	Whole	Waste	Wound Urban	Whose	Watch	Write Usage	Woman	Water	Wrong Usual	Train	Wheel	Wrote Valid	World	Where	Yield Value	Worry	Which	Young Video	Worse	While	Youth "Virus",	"Worst", "White",	"Worth", "Visit",	"Would", "Vital",	"Voice"]  # Example word list
    return random.choice(words).upper(),

def check_guess(secret_word, guess):
    result = ""
    secret_word_list = list(secret_word)
    for i in range(len(guess)):
        if guess[i] == secret_word[i]:
            result += "🟩"
            secret_word_list[i] = ""  # Mark the letter as used
        elif guess[i] in secret_word_list:
            result += "🟨"
            secret_word_list[secret_word_list.index(guess[i])] = "" # Mark the letter as used
        else:
            result += "⬜"
    return result


def play_wordle():
    secret_word = choose_word()
    attempts = 6

    print("Welcome to Wordle!")

    for _ in range(attempts):
        guess = input("Enter your guess: ").upper()

        if len(guess) != 5:
            print("Invalid guess. Please enter a 5-letter word.")
            continue

        result = check_guess(secret_word, guess)
        print(result)

        if guess == secret_word:
            print("Congratulations! You guessed the word!")
            return

    print(f"You ran out of attempts. The word was {secret_word}")
play_wordle()
